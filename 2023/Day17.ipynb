# %%
from tqdm import tqdm
import numpy as np
import networkx as nx

# %% [markdown]
# ## Part 1

# %%
def generate_long_star_graph(center_pos_yx):
    G = Graph()
    
    
    
    
    
    
    
    return Graph()

# %%
lines = open("Day17_input.txt").read().splitlines()

n_rows = len(lines)
n_cols = len(lines[0])
current_pos = [0,0]
final_pos = [n_rows-1, n_cols-1]

Crosses = [[None for xdx in range(n_rows)] for ydx in range(n_cols)]
Grid=nx.grid_2d_graph(n_rows, n_cols)
Grid.remove_edges_from(Grid.edges())
for ydx in range(n_cols):
    for xdx in range(n_rows):
        Crosses
        
        Grid.nodes[(ydx, xdx)]['weight'] = lines[ydx][xdx]
        print(Grid.nodes[(ydx, xdx)])
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[35], line 9
#       5 current_pos = [0,0]
#       6 final_pos = [n_rows-1, n_cols-1]
# ----> 9 Grid=nx.Graph(n_rows*n_cols)
#      10 for ydx in range(n_cols):
#      11     for xdx in range(n_rows):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\networkx\classes\graph.py:370, in Graph.__init__(self, incoming_graph_data, **attr)
#     368 # attempt to load graph with data
#     369 if incoming_graph_data is not None:
# --> 370     convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     371 # load graph attributes (must be after convert)
#     372 self.graph.update(attr)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\networkx\convert.py:176, in to_networkx_graph(data, create_using, multigraph_input)
#     173     except Exception as err:
# ...

# %%
Grid=nx.grid_2d_graph(5,5)
Grid.remove_edges_from(Grid.edges())


nx.draw(Grid, with_labels=True, font_weight='bold')

# %% [markdown]
# ## Part 2
